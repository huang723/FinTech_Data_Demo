# %%
# %pip install openpyxl
#pro = ts.pro_api('your token')
pro = ts.pro_api('your_token_here')
df = pro.daily(ts_code='600519.SH', start_date='20250101', end_date='20251231')

df.to_excel('maotai_daily_2025.xlsx')
# Out:
#   Cell In[15], line 3
#     pro = ts.pro_api('your_token_here)
#                      ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# %pip install matplotlib
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_excel('maotai_daily_2025.xlsx')
df.index=pd.to_datetime(df['trade_date'])
df=df.sort_index()

import matplotlib_inline
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

df['MA5']=df['close'].rolling(5).mean()
df['MA30']=df['close'].rolling(30).mean()
df[['close','MA5','MA30']].plot(figsize=(12,6),title='贵州茅台2025股均线分析系统',grid=True)
plt.savefig('maotai_daily_2025.png',dpi=300)
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
